# %%
import pandas as pd
import numpy as np

booksdf = pd.read_csv("books.csv")
booksdf = booksdf.drop(labels=["Edition Statement", \
                                "Corporate Author", \
                                "Corporate Contributors", \
                                "Former owner", \
                                "Engraver", \
                                "Issuance type", \
                                "Shelfmarks"], axis=1)
booksdf.head(3)
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
#
#       Author                                  Contributors  \
# 0      A. A.                               FORBES, Walter.
# 1  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness
# 2  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness
#
#                                           Flickr URL
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# ...

# %%
booksdf2 = pd.read_csv("books.csv", usecols=['Identifier', \
                                             'Place of Publication', \
                                             'Date of Publication', \
                                             'Publisher', \
                                             'Title', \
                                             'Author', \
                                             'Contributors', \
                                             'Flickr URL'])
booksdf2.head(3)
print(len(booksdf2))
# Out:
# 8287

# %%
good_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==True]
bad_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==False]
nan_dates = booksdf[booksdf['Date of Publication'].isna()]
print(f"good dates {len(good_dates)}")
print(f"bad dates {len(bad_dates)}")
print(f"nan dates {len(nan_dates)}")
print(f"total dates {len(good_dates) + len(bad_dates) + len(nan_dates)}")
# Out:
# good dates 6528
# bad dates 1578
# nan dates 181
# total dates 8287

# %%
booksdf = booksdf.replace({'Date of Publication': r'.*\?.*'}, {'Date of Publication': np.nan}, regex=True)
good_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==True]
bad_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==False]
nan_dates = booksdf[booksdf['Date of Publication'].isna()]
print(f"good dates {len(good_dates)}")
print(f"bad dates {len(bad_dates)}")
print(f"nan dates {len(nan_dates)}")
print(f"total dates {len(good_dates) + len(bad_dates) + len(nan_dates)}")
# Out:
# good dates 6528
# bad dates 1459
# nan dates 300
# total dates 8287

# %%
booksdf = booksdf.replace({'Date of Publication': r'^(\d{4})(.*)'}, {'Date of Publication': r'\1'}, regex=True)
good_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==True]
bad_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==False]
nan_dates = booksdf[booksdf['Date of Publication'].isna()]
print(f"good dates {len(good_dates)}")
print(f"bad dates {len(bad_dates)}")
print(f"nan dates {len(nan_dates)}")
print(f"total dates {len(good_dates) + len(bad_dates) + len(nan_dates)}")
# Out:
# good dates 7288
# bad dates 699
# nan dates 300
# total dates 8287

# %%
booksdf['Date of Publication'] = booksdf['Date of Publication'].str.strip('[')
booksdf['Date of Publication'] = booksdf['Date of Publication'].str.strip(']')
booksdf['Date of Publication'] = booksdf['Date of Publication'].str.strip('.')
good_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==True]
bad_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==False]
nan_dates = booksdf[booksdf['Date of Publication'].isna()]
print(f"good dates {len(good_dates)}")
print(f"bad dates {len(bad_dates)}")
print(f"nan dates {len(nan_dates)}")
print(f"total dates {len(good_dates) + len(bad_dates) + len(nan_dates)}")
# Out:
# good dates 7905
# bad dates 82
# nan dates 300
# total dates 8287

# %%
booksdf = booksdf.replace({'Date of Publication': r'^(\d{4})(.*)'}, {'Date of Publication': r'\1'}, regex=True)
good_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==True]
bad_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==False]
nan_dates = booksdf[booksdf['Date of Publication'].isna()]
print(f"good dates {len(good_dates)}")
print(f"bad dates {len(bad_dates)}")
print(f"nan dates {len(nan_dates)}")
print(f"total dates {len(good_dates) + len(bad_dates) + len(nan_dates)}")
# Out:
# good dates 7976
# bad dates 11
# nan dates 300
# total dates 8287

# %%
booksdf = booksdf.replace({'Date of Publication': r'(.*)(\d{4})(.*)'}, {'Date of Publication': r'\2'}, regex=True)
good_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==True]
bad_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==False]
nan_dates = booksdf[booksdf['Date of Publication'].isna()]
print(f"good dates {len(good_dates)}")
print(f"bad dates {len(bad_dates)}")
print(f"nan dates {len(nan_dates)}")
print(f"total dates {len(good_dates) + len(bad_dates) + len(nan_dates)}")
# Out:
# good dates 7985
# bad dates 2
# nan dates 300
# total dates 8287

# %%
booksdf = booksdf.replace({'Date of Publication': r'^(?:(?!\d{4}).)+$'}, {'Date of Publication': np.nan}, regex=True)
good_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==True]
bad_dates = booksdf[booksdf['Date of Publication'].str.match('^\d{4}$')==False]
nan_dates = booksdf[booksdf['Date of Publication'].isna()]
print(f"good dates {len(good_dates)}")
print(f"bad dates {len(bad_dates)}")
print(f"nan dates {len(nan_dates)}")
print(f"total dates {len(good_dates) + len(bad_dates) + len(nan_dates)}")
# Out:
# good dates 7985
# bad dates 0
# nan dates 302
# total dates 8287

# %%
booksdf['Place of Publication'] = booksdf['Place of Publication'].replace('(.*),(.*)', '\1')

# %%
bad_place = booksdf[booksdf['Place of Publication'].str.match(r'.*[,;:].*')==True]
bad_place['Place of Publication'].tolist()
# Out:
# ['London; Virtue & Yorston',
#  'pp. 40. G. Bryan & Co: Oxford, 1898',
#  'pp. 40. W. Cann: Plymouth, [1876?]',
#  'Carlstad, Stockholm',
#  'Cambridge, [Mass.]',
#  'Edinburgh; John Murray',
#  'pp. vi. 216. Hatchards: London, 1888',
#  'J. Vincent; London',
#  'London; Oxford',
#  'New York, London',
#  'pp. 64. W. Cann: Plymouth, [1870?]',
#  'Meriden, Conn',
#  'Paris; Moulins',
#  'T. C. Newby; London',
#  'pp. 95. Erskine Macdonald: London, 1921',
#  'pp. xi. 59. J. Parker & Co.: Oxford, [1900.]',
#  'Hartford, Conn',
#  'Springfield, Mass',
#  'Phila., Pa',
#  'Edinburgh; reprinted by B. Dewhirst',
#  'Cooperstown, N.Y',
#  'Newark, N.J',
#  'Windsor, Vt',
#  'London; W. Frederick',
#  'Springfield, O',
#  'Dover, N.H',
#  'pp. xii. 59. Thomas Burleigh: London, 1900',
#  'Москва, 1857-60',
#  'Richmond, Va',
#  'London; F. P. Harper',
#  'pp. 92. Heath Cranton: London, 1919',
#  'pp. x. 429. John Murray: London, 1894',
#  '2 vol. W. Blackwood & Sons: Edinburgh, 1888',
# ...
